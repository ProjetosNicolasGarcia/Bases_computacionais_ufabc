# %%
n = 7200
h = int(n / 3600)
segs_restando_dps_das_horas = n % 3600
m = int(segs_restando_dps_das_horas / 60)
s = segs_restando_dps_das_horas % 60

# %%
print(str(h).zfill(2), ":", str(m).zfill(2), ":", str(s).zfill(2))
# Out:
# 02 : 00 : 00

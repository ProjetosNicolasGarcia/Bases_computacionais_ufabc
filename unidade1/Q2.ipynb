# %%
C = [55, 65]

# %%
F= (((C[0] * (9/5)) + 32), (C[1] * (9/5)) + 32)

# %%
print(C[0], "graus Celsius correspondem a", F[0],"graus Fahreinheit")
print(C[1], "graus Celsius correspondem a", F[1],"graus Fahreinheit")
# Out:
# 55 graus Celsius correspondem a 131.0 graus Fahreinheit
# 65 graus Celsius correspondem a 149.0 graus Fahreinheit

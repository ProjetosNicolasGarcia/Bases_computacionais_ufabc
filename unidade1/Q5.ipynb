# %%
import math

# %%
a = 1
b = 2
x = 1.1
y = 2.2

# %%
# e = (a + (b ** x)) - (math.sqrt(b) + ((a + b) / (x - y))) #

# %%
 e = a + (b ** x) - math.sqrt(b) + (a + b) / (x - y)

# %%
valor_do_circulo = round(e)

# %%
print('expressão:', valor_do_circulo)
# Out:
# expressão: -1
